# %%
# C1 データ分析エンジニアの役割(2, 5.0%)

# データサイエンティストの役割
# 研究分野：新たな解法や新技術への取り組み
# 実務：解決したい課題に向き合う部分

# 機械学習以外の選択肢
# ルールベース(if文)
# 統計的な手法

# 教師あり学習
# 正解となるラベルデータが存在する(目的変数) ⇄ 特徴データや特徴量(説明変数)
    # 回帰と分類
    # 回帰は目的変数が連続値
    # 分類は目的変数が連続値でない
    
# 教師なし学習
# 正解ラベルを用いない学習方法
# クラスタリングや次元削減

# 強化学習

# 1
# 教師なし学習の１つであるDBSCAN法は密度準拠クラスタリングアルゴリズムであり、特徴量ベクトル間の距離に着眼した手法である。

# 2
# Pythonでデータ分析に使われる主なパッケージには、Jupyter Notebook、NumPy、pandas、Matplotlib、Scipy、scikit-learnなどがある。

# %%
# C2 Pythonと環境(5, 12.5%)

# PEP 8に違反していないかチェックするツール pycodestyle
# 論理的なチェックを行う Flake8

# リスト内表記は[]
# セット内表記は{}

# リスト内表記と同じ書き方で()で定義するとジェネレーター式

# %または%%からはじまるマジックコマンド
# プログラムの実行時間の計測などが可能

# セルに!を入力して、続けてOSのコマンドを指定してシェルコマンドが実行できる

# %%
# C3 数学の基礎(6, 15.0%)

# 指数関数
# 関数の入力が別の数字の肩に乗って使われる関数
# シグモイド関数
# xが大きな値をとると1に近づき、xが小さい値をとると0に近づく

# 対数関数
# 入力された値が、底の何乗に相当するかを出力する
# 底がネイピア数の時を特に、自然対数
# 底が10の時は常用対数
# 底が省略されている場合は10なのかネイピアなのか注意が必要
# 対数関数のグラフはxが正の値だけで定義できる

# 三角関数
# sinθ「サイン」 = 正弦、cosθ「コサイン」=余弦
# tanθ「タンジェント」= 正接 = sinθ / cosθ

# 8
#指数関数を応用した関数にシグモイド関数がある。シグモイド関数は、深層学習の基本的な技術であるニューラルネットワークでよく使われる。
#シグモイド関数のグラフの形は、座標点（0, 0.5）を基点として点対象の、S字型曲線である。
#数式で足し算の繰り返しを表す際には、ギリシャ文字のシグマの大文字を用い、プログラムではそのままは実行できない「無限大まで足し算を繰り返す」という動作も表現できる。
#ネイピア数とは数学定数の一つで、指数対数の底であり、通常「e」の記号で表現される。対数関数で底が省略された場合には、「e」なのか「10」なのかは注意が必要である。
#三角関数では、角度の大きさを表す単位として度数法のほかに弧度法が使われる。

# 行列
# 行と列のサイズが同じ行列を正方行列
# 対角成分がすべて1で、残りの要素が0の行列を単位行列
# 行列の列の数とベクトルのサイズが同じ場合は掛け算ができる

# 10
#行と列のサイズが同じ行列を特に正方行列と呼ぶ。正方行列のうち、対角成分がすべて1で、残りの要素が0の行列を単位行列と呼ぶ。
#ベクトルと同じように要素同士の足し算と引き算で、行列の足し算と引き算を定義することができるが、2つの行列の行数と列数が合っている必要がある。
#行列の列の数とベクトルのサイズが同じ場合は、これらの掛け算を定義することができ、結果は、元の行列の行数と同じサイズのベクトルになる。
#行列同士の掛け算は行列となる。数値の掛け算は順番を入れ替えても同じ結果となるが、行列の掛け算は順番を入れ替えると同じ結果になるとは限らない。
#行列の分解の理論「m×sの行列にs×nの行列を賭けると、m×nの行列になる」を逆に考えると、データ分析や機械学習において、説明変数の次元数を削減することができる。

# 微分積分
# 関数F(x)を微分してf(x)になる
# Fをfの原始関数、fをFの導関数
# Cは不定積分ではおまけのようについてくる

# 11
#関数 F(x)を微分して f(x)となったとき、F を f の原始関数、f を F の導関数と呼ぶ。
#積分の範囲が定められていない積分を不定積分という。任意の定数を微分すると0になるため、不定積分には積分定数「C」が通常含まれる。
#微分は傾き、積分は面積と捉えることができる。データ分析や機械学習において、関数の傾きが0となる点は有益な情報として利用される。
#2つ以上の変数を持つ多変数関数の微分を偏微分という。偏微分ではどの変数で微分したのかを示すことが必要である。

# 統計
# 相関関数は-1から1の間
# 共分散を2つの変数の標準偏差で割った値
# 共分散はそれぞれの変数について平均値との差の掛け算
# 相関関数 = ピアソンの積率相関係数
# スピアマンの順位相関関数
# データの順番だけ注目して計算される

# 確率
# 確率変数が離散的な場合、確率質量関数
# 確率変数が連続的な場合、確率密度関数

# x = 0の時に最も高い値　→　正規分布
#  平均が0、分散が1 →　標準正規分布

# 1の対数 = 0
# 0の階乗 = 1
